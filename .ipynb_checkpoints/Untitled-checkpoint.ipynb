# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
housing = pd.read_csv("data.csv")

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
corr_matrix= housing.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending= False)
# Out:
# MEDV       1.000000
# RM         0.696169
# ZN         0.360445
# B          0.333461
# DIS        0.249929
# CHAS       0.175260
# AGE       -0.376955
# RAD       -0.381626
# CRIM      -0.388305
# NOX       -0.427321
# TAX       -0.468536
# INDUS     -0.483725
# PTRATIO   -0.507787
# LSTAT     -0.737663
# Name: MEDV, dtype: float64

# %%
attributes = ["MEDV", "RM", "ZN", "LSTAT"]
scatter_matrix(housing[attributes])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028410ED3B38>,
# ...
#       dtype=object)

# %%
housing.plot(kind="scatter" ,x ="RM", y = "MEDV")

# %%
housing["TAXRM"]= housing["TAX"]/housing["RM"]
housing.plot(kind="scatter" ,x ="TAXRM", y = "MEDV")

# %% [markdown]
# ##DEALING WITH MISSING ATTRIBUTES

# %%
# 1.REmove those data ponits from the dataset
# 2. remove the particular column from the dataset
# 3. Replace it with mean of the the whole column

# %%
a = housing.dropna(subset= ["RM"])
a.shape
# Out:
# (501, 15)

# %%
housing.drop("RM", axis =1).shape
# Out:
# (506, 14)

# %%
median = housing["RM"].median()

# %%
housing["RM"].fillna(median)
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy = "median")
imputer.fit(housing)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='median', verbose=0)

# %%
imputer.statistics_
# Out:
# array([2.56510000e-01, 0.00000000e+00, 9.69000000e+00, 0.00000000e+00,
#        5.38000000e-01, 6.20800000e+00, 7.75000000e+01, 3.20745000e+00,
#        5.00000000e+00, 3.30000000e+02, 1.90500000e+01, 3.91440000e+02,
#        1.13600000e+01, 2.12000000e+01, 5.36078965e+01])

# %%
x =imputer.transform(housing)

# %%
housing_tr = pd.DataFrame(x, columns= housing.columns)
housing_tr.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.283587
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702126
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.618750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Sckit LEarn three imp func:
#     Estimators: It estimates some paramaeters based on the dataset.Eg Imputer. It has two methods fit() and transform() which            helps to fit the training data and calculates the internal parameters and transform data with the transform() method.
#
#     Transformers:takes input and returns output based on the learnings from fit(). It aslso has a convienence function
#         fit_transform() which fits and then transforms the data.
#     Predictors: Linear Regression model is an example of predictor. It has a fit(),predict() method are the common ones.it also         gives  score( ) function which will evaluate the prediction.

# %% [markdown]
#  ##Feature Scaling
# 1.Min-max Scaling (Normalization)
# (value-min)/(max-min)
# Sklearn provides a class MinMaxScaler for this
#
# 2. Standardization
# (value-mean)/std
# Sklearn provides a clas StandardScaler for this.
